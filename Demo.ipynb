# %%
# %sql
ALTER TABLE wine_review SET TBLPROPERTIES (delta.enableChangeDataFeed = true)

# %%
# %sql
CREATE OR REPLACE TABLE workspace.default.winemag_data_130_k_v_2 AS
SELECT
  ROW_NUMBER() OVER (ORDER BY title) AS row_num,
  *
FROM workspace.default.winemag_data_130_k_v_2;

# %%
# %sql
CREATE OR REPLACE TABLE workspace.default.winemag_data_130_k_v_2 AS
SELECT *
FROM workspace.default.winemag_data_130_k_v_2
LIMIT 100

# %%
# %sql
SELECT *
FROM vector_search(
  index => "workspace.default.demo_vsi",
  query_text => "cherry",
  query_type => "HYBRID", --HYBRID --LEXICAL --VECTOR
  num_results => 5
)

# %%
# %python
# %pip install databricks-vectorsearch 
dbutils.library.restartPython()

# %%
# %python
from databricks.vector_search.client import VectorSearchClient
from databricks.sdk import WorkspaceClient
# Initialize client
w = WorkspaceClient()
vsc = VectorSearchClient(disable_notice=True)
# Get the index
index = vsc.get_index(index_name="workspace.default.demo_vsi")
# Run a similarity search using text
results = index.similarity_search(
query_text = "vanill cherry",
columns = ["row_num", "description"], # only return these columns
num_results = 5,
disable_notice=True
)

# %%
print(results["result"]["data_array"])
